# %%
import matplotlib.pyplot as plt

# %%
epochs = list(range(1, 11))

# %%
SIMPLE_CNN_TRAIN =  [0.7607, 0.8558, 0.8778, 0.8873, 0.8981, 0.9067, 0.9125, 0.9172, 0.9237, 0.9271]
SIMPLE_CNN_TRAIN = [x * 100 for x in SIMPLE_CNN_TRAIN]
SIMPLE_CNN_TEST =   [0.8163, 0.8632, 0.8772, 0.8802, 0.8908, 0.8916, 0.8992, 0.8988, 0.9051, 0.9041]
SIMPLE_CNN_TEST = [x * 100 for x in SIMPLE_CNN_TEST]

# %%
SIMPLE_VGG16_TRAIN = [86.46,90.855,92.34166666666667,93.03,93.76666666666667,94.20666666666666,94.71666666666667,95.09166666666667,95.57333333333334,96.06666666666666]
SIMPLE_VGG16_TEST = [89.52675718849841,90.70487220447285,91.45367412140575,91.75319488817891,91.85303514376997,91.72324281150159,91.51357827476038,92.60183706070288,92.40215654952077,92.72164536741214]

# %%
SIMPLE_VIT_TRAIN = [69.79666666666667, 79.66833333333334, 81.36333333333333, 82.105, 83.18833333333333, 83.65666666666667, 84.435, 85.05166666666666, 85.64833333333333, 86.26166666666667]
SIMPLE_VIT_TEST = [76.72, 79.98, 79.44, 81.46, 81.03, 81.05, 82.35, 83.01, 83.52, 82.3]

# %%
# Create the plot
plt.figure(figsize=(10, 6))

plt.plot(epochs, SIMPLE_CNN_TRAIN,marker='o',label='CNN (Train)')
plt.plot(epochs, SIMPLE_VGG16_TRAIN,marker='o', label='VGG16 (Train)')
plt.plot(epochs, SIMPLE_VIT_TRAIN,marker='o', label='ViT (Train)')

plt.plot(epochs, SIMPLE_CNN_TEST,marker='o', linestyle='--', label='CNN (Test)')
plt.plot(epochs, SIMPLE_VGG16_TEST,marker='o', linestyle='--',label='VGG16 (Test)')
plt.plot(epochs, SIMPLE_VIT_TEST,marker='o', linestyle='--', label= 'ViT (Test)')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Training and Testing Accuracy')
plt.legend()
plt.grid(True)

# %%
SIMPLE_VIT_TRAIN_CUTMIX =[44.585, 55.64, 58.04666666666667, 57.815, 58.685, 59.376666666666665, 60.70666666666666, 62.07, 61.405, 61.33]
SIMPLE_VIT_TEST_CUTMIX = [73.9, 77.75, 76.92, 79.54, 79.68, 80.18, 80.99, 80.96, 80.88, 81.37]

# %%
SIMPLE_VIT_TRAIN_MIXUP = [59.165, 70.18166666666667, 72.12166666666667, 73.1, 73.49666666666667, 73.88, 74.10166666666667, 75.405, 74.955, 75.55333333333333]
SIMPLE_VIT_TEST_MIXUP = [76.78, 77.96, 79.72, 81.33, 81.23, 81.79, 81.95, 81.53, 82.44, 82.45]

# %%
SIMPLE_VIT_TRAIN_BOTH_CUTMIX_MIXUP = [47.75, 61.625, 63.42333333333333, 63.44833333333333, 64.04166666666667, 64.77166666666666, 65.85833333333333, 66.31333333333333, 67.99166666666666, 67.465]
SIMPLE_VIT_TEST_BOTH_CUTMIX_MIXUP = [73.57, 78.09, 77.99, 79.42, 80.07, 80.75, 81.0, 80.72, 82.27, 82.26]

# %%
SIMPLE_VIT_TRAIN_RANDOMEARSING = [60.45333333333333, 72.87833333333333, 74.89166666666667, 76.01333333333334, 76.76333333333334, 77.425, 77.875, 78.58166666666666, 78.955, 79.38]
SIMPLE_VIT_TEST_RANDOMEARSING = [69.45, 73.32, 75.33, 74.58, 75.74, 76.97, 77.12, 77.3, 77.47, 78.24]

# %%
# Plot training accuracies
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed
plt.plot(epochs, SIMPLE_VIT_TRAIN, marker='o', label='VIT Train')
#plt.plot(epochs, SIMPLE_VIT_TRAIN_CUTMIX, marker='o', label='VIT + CutMix Train')
##plt.plot(epochs, SIMPLE_VIT_TRAIN_BOTH_CUTMIX_MIXUP, marker='o', label='VIT + CutMix & MixUp Train')
plt.plot(epochs, SIMPLE_VIT_TRAIN_RANDOMEARSING, marker='o', label='VIT + Random Erasing Train')

# Plot testing accuracies
plt.plot(epochs, SIMPLE_VIT_TEST, marker='o', linestyle='--', label='VIT Test')
#plt.plot(epochs, SIMPLE_VIT_TEST_CUTMIX, marker='o', linestyle='--', label='VIT + CutMix Test')
#plt.plot(epochs, SIMPLE_VIT_TEST_MIXUP, marker='o', linestyle='--', label='VIT + MixUp Testi')
#plt.plot(epochs, SIMPLE_VIT_TEST_BOTH_CUTMIX_MIXUP, marker='o', linestyle='--', label='VIT + CutMix & MixUp Testi')
plt.plot(epochs, SIMPLE_VIT_TEST_RANDOMEARSING, marker='o', linestyle='--', label='VIT + Random Erasing Test')

# Add labels and title
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Testing Accuracies for Different Techniques")
plt.legend(loc ='lower right')
plt.grid()
plt.show()

# %%
vgg16_cutmix_train = [86.25,90.75,92.05333333333333,92.85,93.63,94.095,94.57666666666667,95.02833333333334,95.39833333333333,95.835]
vgg16_cutmix_test= [89.77635782747603,90.57507987220447,89.8761980830671,90.54512779552715,92.1026357827476,91.31389776357827,92.13258785942492,92.06269968051119,92.37220447284345,92.37220447284345]

# %%
vgg16_mixup_train = [86.48833333333333,90.95666666666666,92.09833333333333,92.87666666666667,93.61166666666666,94.12833333333333,94.62333333333333,95.025,95.45833333333333,95.94166666666666]
vgg16_mixup_test = [87.02076677316293,90.53514376996804,91.26397763578275,91.65335463258786,92.06269968051119,92.14257188498402,92.20247603833866,92.34225239616613,92.22244408945687,92.1126198083067]

# %%
vgg16_both_train = [86.15166666666667,90.56333333333333,91.78333333333333,92.64833333333333,93.42666666666666,94.00833333333334,94.63833333333334,95.01666666666667,95.51333333333334,95.91833333333334]
vgg16_both_test = [88.81789137380191,90.39536741214057,90.74480830670926,90.19568690095846,91.70327476038338,91.93290734824281,92.0726837060703,91.78314696485623,92.24241214057508,92.02276357827476]

# %%
vgg16_randomerase_train = [83.85166666666667,88.77833333333334,90.14833333333333,91.08833333333334,91.68833333333333,92.14833333333333,92.72166666666666,92.845,93.16166666666666,93.505]
vgg16_randomerase_test = [87.47004792332268,87.8594249201278,89.66653354632588,90.14576677316293,90.84464856230032,90.60503194888179,90.19568690095846,90.92452076677316,90.814696485623,91.46365814696486]

# %%
# Plot training accuracies
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed
plt.plot(epochs, SIMPLE_VGG16_TRAIN, marker='o', label='VGG16 Train')
#plt.plot(epochs, vgg16_cutmix_train, marker='o', label='VGG16 + CutMix Train')
#plt.plot(epochs, vgg16_mixup_train, marker='o', label='VGG16 + MixUp Train')
#plt.plot(epochs, vgg16_both_train, marker='o', label='VGG16 + CutMix & MixUp Train')
plt.plot(epochs, vgg16_randomerase_train, marker='o', label='VGG16 + Random Erasing Train')

# Plot testing accuracies
plt.plot(epochs, SIMPLE_VGG16_TEST, marker='o', linestyle='--', label='VGG16 Test')
#plt.plot(epochs, vgg16_cutmix_test, marker='o', linestyle='--', label='VGG16 + CutMix Test')
#plt.plot(epochs, vgg16_mixup_test, marker='o', linestyle='--', label='VGG16 + MixUp Test')
#plt.plot(epochs, vgg16_both_test, marker='o', linestyle='--', label='VGG16 + CutMix & MixUp Test')
plt.plot(epochs, vgg16_randomerase_test, marker='o', linestyle='--', label='VGG16 + Random Erasing Test')

# Add labels and title
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Testing Accuracies for Different Techniques")
plt.legend(loc ='lower right')
plt.grid()
plt.show()

# %%
CNN_MixUP_Train_Accuracy = [79.34, 87.19,88.56, 89.89, 90.79, 91.43, 92.07, 92.78, 93.38, 93.62]
CNN_MixUp_Test_Accuracy = [84.58, 86.92, 88.29, 89.41, 89.26, 89.94, 90.70, 91.26, 90.90, 91.09]

CNN_CutMix_Train_Accuracy = [79.09, 86.78, 88.56, 89.84, 90.71, 91.34, 92.05, 92.56, 93.17, 93.75]
CNN_CutMix_Test_Accuracy = [84.40, 87.50, 88.51, 89.04, 89.64, 90.23, 90.27, 91.01, 91.02, 91.02]

CNN_Both_Train_Accuracy = [79.02, 86.92, 88.73, 89.86, 90.65, 91.35, 91.93, 92.69, 93.13, 93.82]
CNN_Both_Test_Accuracy = [82.53, 87.05, 88.48, 89.31, 89.48, 90.02, 89.79, 90.95, 91.41, 91.05]

CNN_RandomErasing_Train_Accuracy = [75.02, 83.92, 85.84, 87.41, 88.38, 88.90, 89.67, 89.99, 90.34, 90.84]
CNN_RandomErasing_Test_Accuracy = [81.70, 84.83, 85.93, 86.87, 87.69, 88.39, 88.16, 88.16, 89.15, 89.32]

# %%
# Plot training accuracies
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed
plt.plot(epochs, SIMPLE_CNN_TRAIN, marker='o', label='CNN Train')
#plt.plot(epochs, CNN_CutMix_Train_Accuracy, marker='o', label='CNN + CutMix Train')
#plt.plot(epochs, CNN_MixUP_Train_Accuracy, marker='o', label='CNN + MixUp Train')
#plt.plot(epochs, CNN_Both_Train_Accuracy, marker='o', label='CNN + CutMix & MixUp Train')
plt.plot(epochs, CNN_RandomErasing_Train_Accuracy, marker='o', label='CNN + Random Erasing Train')

# Plot testing accuracies
plt.plot(epochs, SIMPLE_CNN_TEST, marker='o', linestyle='--', label='CNN Test')
#plt.plot(epochs, CNN_CutMix_Test_Accuracy, marker='o', linestyle='--', label='CNN + CutMix Test')
#plt.plot(epochs, CNN_MixUp_Test_Accuracy, marker='o', linestyle='--', label='CNN + MixUp Test')
#plt.plot(epochs, CNN_Both_Test_Accuracy, marker='o', linestyle='--', label='CNN + CutMix & MixUp Test')
plt.plot(epochs, CNN_RandomErasing_Test_Accuracy, marker='o', linestyle='--', label='CNN + Random Erasing Test')

# Add labels and title
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training and Testing Accuracies for Different Techniques")
plt.legend(loc ='lower right')
plt.grid()
plt.show()
